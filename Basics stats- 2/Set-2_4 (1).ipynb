# %%
from scipy import stats
from scipy.stats import norm

# %%
# mean = 100, std_dev = 20, confidence interval = 0.99
stats.norm.interval(0.99, 100,20)
# Out:
# (48.48341392902199, 151.516586070978)
