# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b964ebe1-4b15-4dcb-b8e2-9d89e7776097" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b964ebe1-4b15-4dcb-b8e2-9d89e7776097">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
LabTAT = pd.read_csv("LabTAT.csv")

# %%
LabTAT.shape
# Out:
# (120, 4)

# %%
LabTAT.value_counts('Laboratory 1')
# Out:
# Laboratory 1
# 168.62    2
# 138.30    1
# 187.18    1
# 186.22    1
# 185.87    1
#          ..
# 172.02    1
# 172.00    1
# 171.65    1
# 171.64    1
# 216.39    1
# Length: 119, dtype: int64

# %%
LabTAT.value_counts('Laboratory 2','Laboratory 3', 'Laboratory 4' )
# Out:
# Laboratory 2
# 168.20    0.016667
# 179.43    0.008333
# 189.11    0.008333
# 188.49    0.008333
# 187.57    0.008333
#             ...
# 169.60    0.008333
# 169.57    0.008333
# 169.11    0.008333
# 168.80    0.008333
# 217.86    0.008333
# Length: 119, dtype: float64

# %%
from scipy import stats
lab = stats.f_oneway(LabTAT['Laboratory 1'],LabTAT['Laboratory 2'],LabTAT['Laboratory 3'],LabTAT['Laboratory 4'])
lab
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
lab
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)
