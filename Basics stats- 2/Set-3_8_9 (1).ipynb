# %% [markdown]
# Q 8

# %%
Z = 1.96
p = 0.5
e = 0.04
n = ((Z**2)*p*(1-p)/(e**2))
n
# Out:
# 600.2499999999999

# %% [markdown]
# Q 9

# %%
z = 2.326
p = 0.5
e = 0.04
n = ((z**2)*p*(1-p)/(e**2))
n
# Out:
# 845.355625
